# %%
# ---- 4.1 Logistic Regression ----
# Removed class_weight='balanced' since SMOTE already balanced it
lr = LogisticRegression(max_iter=2000, random_state=42)
lr.fit(X_train, y_train)
lr_results = evaluate_model(lr, X_test, y_test, "Logistic Regression")

# %%
# ---- 4.2 Random Forest ----
# Increased estimators to 500 for maximum accuracy
rf = RandomForestClassifier(n_estimators=500, random_state=42, n_jobs=-1)
rf.fit(X_train, y_train)
rf_results = evaluate_model(rf, X_test, y_test, "Random Forest")

# %%
# ---- 4.3 LightGBM ----
lgbm = LGBMClassifier(
    objective='binary',
    n_estimators=500,
    max_depth=8,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    verbose=-1
)
lgbm.fit(X_train, y_train)
lgbm_results = evaluate_model(lgbm, X_test, y_test, "LightGBM")

# %%
# ---- 4.4 XGBoost (Main Model) ----
xgb = XGBClassifier(
    objective='binary:logistic',
    n_estimators=500,
    max_depth=8,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    eval_metric='logloss'
)
xgb.fit(X_train, y_train)
xgb_results = evaluate_model(xgb, X_test, y_test, "XGBoost")

# %%
# Confusion Matrix for XGBoost
y_pred_xgb = xgb.predict(X_test)
cm_xgb = confusion_matrix(y_test, y_pred_xgb)
plt.figure(figsize=(6,5))
sns.heatmap(cm_xgb, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Not Potable', 'Potable'],
            yticklabels=['Not Potable', 'Potable'])
plt.title('XGBoost Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
# ROC Curve for XGBoost
y_proba_xgb = xgb.predict_proba(X_test)[:, 1]
fpr_xgb, tpr_xgb, _ = roc_curve(y_test, y_proba_xgb)
roc_auc_xgb = auc(fpr_xgb, tpr_xgb)

plt.figure(figsize=(8,6))
plt.plot(fpr_xgb, tpr_xgb, color='darkorange', lw=2,
         label=f'XGBoost (AUC = {roc_auc_xgb:.3f})')
plt.plot([0, 1], [0, 1], 'k--', label='Random')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('XGBoost ROC Curve')
plt.legend(loc="lower right")
plt.grid(alpha=0.3)
plt.show()
